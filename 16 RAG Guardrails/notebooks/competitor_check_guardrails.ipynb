# %%
from guardrails import Guard
from guardrails_ai.competitor_check import CompetitorCheck
from dotenv import load_dotenv

# %%
# load the env vars
load_dotenv()
# Out:
# True

# %%
# create the validator

competitor_list = ["Apple", "Google", "Microsoft", "Samsung", "Amazon"]

validator = CompetitorCheck(competitors=competitor_list,
                            on_fail="exception")

# create guard and add the validator to the guard
guard = Guard().use(validator)

# %%
# validate the user input

user_input_1 = "I like all the fruits, but apple and grapes are my favorite."
user_input_2 = "Apple is great, makes durable and high quality products."

response_1 = guard.validate(user_input_1)
# Out:
# e:\Machine Learning and Data Science\Advanced-RAGs-Detailed\.venv\Lib\site-packages\guardrails\validator_service\__init__.py:81: UserWarning: Could not obtain an event loop. Falling back to synchronous validation.
#   warnings.warn(
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 0.82s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 1.68s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 4.52s.
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 1.04s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 1.91s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 4.10s.
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.

# %%
response_1
# Out:
# ValidationOutcome[~OT](call_id='1786726788352', raw_llm_output='I like all the fruits, but apple and grapes are my favorite.', validation_summaries=[], validated_output='I like all the fruits, but apple and grapes are my favorite.', reask=None, validation_passed=True, error=None)

# %%
print(f"Validation Result: {response_1.validation_passed}")
print(f"Raw User Input: {response_1.raw_llm_output}")
print(f"Validated Output: {response_1.validated_output}")
# Out:
# Validation Result: True
# Raw User Input: I like all the fruits, but apple and grapes are my favorite.
# Validated Output: I like all the fruits, but apple and grapes are my favorite.

# %%
try: 
    response_2 = guard.validate(user_input_2)
except Exception as e:
    print(e)
# Out:
# Validation failed for field with errors: Found the following competitors: Apple. Please avoid naming those competitors next time
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 1.00s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 1.68s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Max retries exceeded with url: /v1/traces (Caused by NameResolutionError("HTTPSConnection(host='hty0gc1ok3.execute-api.us-east-1.amazonaws.com', port=443): Failed to resolve 'hty0gc1ok3.execute-api.us-east-1.amazonaws.com' ([Errno 11001] getaddrinfo failed)")) encountered while exporting span batch, retrying in 4.38s.
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.
